# %% [markdown]
# # Lab 3 Part V: Image Autoencoder with CNNs
#
# ------------------------------------------------------
# *Deep Learning. Master in Information Health Engineering *
#
# *Pablo M. Olmos pamartin@ing.uc3m.es*
#
# ------------------------------------------------------
#
# In this notebook, we'll build a convolutional autoencoder to compress the MNIST dataset. Then, we will extend the code to implement a denoising autoencoders. The encoder portion will be made of convolutional and pooling layers and the decoder will be made of **transpose convolutional layers** that learn to "upsample" a compressed representation.
#
# Note: a big part of the following material is a personal wrap-up of [Facebook's Deep Learning Course in Udacity](https://www.udacity.com/course/deep-learning-pytorch--ud188). So all credit goes for them!!

# %%
from IPython.display import Image
from IPython.core.display import HTML 

Image(url= "https://iq.opengenus.org/content/images/2019/03/autoencoder_1.png", width=800, height=200)
# Out:
# <img src="https://iq.opengenus.org/content/images/2019/03/autoencoder_1.png" width="800" height="200"/>

# %% [markdown]
# ## Part I. Load MNIST. Visualize images

# %%
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# load the training and test datasets
train_data = datasets.MNIST(root='data', train=True,
                                   download=True, transform=transform)
test_data = datasets.MNIST(root='data', train=False,
                                  download=True, transform=transform)
# Out:
# 0it [00:00, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# 9920512it [00:06, 1633420.64it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# 32768it [00:00, 135981.77it/s]
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 1654784it [00:00, 2314869.02it/s]
# 0it [00:00, ?it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 8192it [00:00, 53954.42it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
# Processing...
# Done!

# %% [markdown]
# > **Exercise**: Load the data using the DataLoader class ...

# %%
# how many samples per batch to load
batch_size = 128

# prepare data loaders

trainloader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
testloader = torch.utils.data.DataLoader(test_data, batch_size=batch_size)

# %% [markdown]
# > **Exercise:** Create a validation set with 5000 images

# %%
import copy

validloader = copy.deepcopy(trainloader)  # Creates a copy of the object 

#We take the first 48k images for training
trainloader.dataset.data = trainloader.dataset.data[:5000,:,:]
trainloader.dataset.targets = trainloader.dataset.targets[:5000]

#And the rest for validation
validloader.dataset.data = validloader.dataset.data[5000:,:,:]
validloader.dataset.targets = validloader.dataset.targets[5000:]

# %% [markdown]
# > **Exercise:** Complete the following code to visualize an image. What does `np.squeeze()` do?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
    
# obtain one batch of training images
dataiteretor = iter(trainloader)
images, labels = dataiteretor.next()
images = images.numpy()

# get one image from the batch
img = np.squeeze(images[1])

fig = plt.figure(figsize = (5,5)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')

# %% [markdown]
# ---
# ## Part II. Create the convolutional  autoencoder
#
# #### Encoder
# The encoder part of the network will be a typical convolutional pyramid. Each convolutional layer will be followed by a max-pooling layer to reduce the dimensions of the layers.
#
# #### Decoder
#
# The decoder though might be something new to you. The decoder needs to convert from a narrow representation to a wide, reconstructed image. For example, the representation could be a 7x7x4 max-pool layer. This is the output of the encoder, but also the input to the decoder. We want to get a 28x28x1 image out from the decoder so we need to work our way back up from the compressed representation. A schematic of the network is shown below.

# %%
Image(url= "https://iq.opengenus.org/content/images/2019/03/autoencoder_3.png", width=400, height=200)
# Out:
# <img src="https://iq.opengenus.org/content/images/2019/03/autoencoder_3.png" width="400" height="200"/>

# %% [markdown]
# Here our final encoder layer has size 7x7x4 = 196. The original images have size 28x28 = 784, so the encoded vector is 25% the size of the original image. These are just suggested sizes for each of the layers. Feel free to change the depths and sizes, in fact, you're encouraged to add additional layers to make this representation even smaller! Remember our goal here is to find a small representation of the input data.
#
# ### Transpose Convolutions, Decoder
#
# This decoder uses **transposed convolutional** layers to increase the width and height of the input layers. They work almost exactly the same as convolutional layers, but in reverse. A stride in the input layer results in a larger stride in the transposed convolution layer. For example, if you have a 3x3 kernel, a 3x3 patch in the input layer will be reduced to one unit in a convolutional layer. Comparatively, one unit in the input layer will be expanded to a 3x3 path in a transposed convolution layer. PyTorch provides us with an easy way to create the layers, [`nn.ConvTranspose2d`](https://pytorch.org/docs/stable/nn.html#convtranspose2d).
#
# It is important to note that transpose convolution layers can lead to artifacts in the final images, such as checkerboard patterns. This is due to overlap in the kernels which can be avoided by setting the stride and kernel size equal. In [this Distill article](http://distill.pub/2016/deconv-checkerboard/) from Augustus Odena, *et al*, the authors show that these checkerboard artifacts can be avoided by resizing the layers using nearest neighbor or bilinear interpolation (upsampling) followed by a convolutional layer.
#
# > **Exercise:** Complete the following code, in which we build the autoencoder using a series of convolutional layers, pooling layers, and transpose convolutional layers. When building the decoder, recall that transpose convolutional layers can upsample an input by a factor of 2 using a stride and kernel_size of 2.

# %%
import torch.nn as nn
import torch.nn.functional as functional
from torch import optim
import time

# define the NN architecture
class ConvAutoencoder(nn.Module):
    def __init__(self):
        super().__init__()
        
        ## Encoder layers ##
        # conv layer (depth from 1 --> 16), 3x3 kernels
        self.conv1 = nn.Conv2d(1, 16, 3, padding=1)   
        # conv layer (depth from 16 --> 4), 3x3 kernels
        self.conv2 = nn.Conv2d(16, 4, 3, padding=1)  
        # pooling layer to reduce x-y dims by two; kernel and stride of 2
        self.pool = nn.MaxPool2d(2, 2)
        
        ## decoder layers ##
        ## a kernel of 2 and a stride of 2 will increase the spatial dims by 2
        self.t_conv1 = nn.ConvTranspose2d(4, 16, 2, stride=2)
        self.t_conv2 = nn.ConvTranspose2d(16, 1, 2, stride=2)

    def forward(self, x):

        x = functional.relu(self.conv1(x))
        x = self.pool(x)
        x = functional.relu(self.conv2(x))

        latent = self.pool(x)

        x = functional.relu(self.t_conv1(latent))
        x = torch.sigmoid(self.t_conv2(x))

        return x, latent

# %% [markdown]
# ---
# ## Part III. Training
#
# > **Exercise:** Extend the class implemented above to inlude a training method which monitors the reconstrution loss in both the training and validation datasets. In [this blog](https://medium.com/udacity-pytorch-challengers/a-brief-overview-of-loss-functions-in-pytorch-c0ddb78068f7) you can find a good summary of Pytorch Loss Functions. For the problem at hand, decide which one is more convenient.

# %%
class ConvAutoencoderExtended(ConvAutoencoder):
    
    def __init__(self,epochs=100,lr=0.001):
        
        super().__init__() 
        
        self.lr = lr 
        
        self.optim = optim.Adam(self.parameters(), self.lr)
        
        self.epochs = epochs
        
        self.criterion = nn.SmoothL1Loss()
        
        self.loss_during_training = []
        
        self.validation_loss_during_training = []
    
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        self.to(self.device)
        
    def trainloop(self,trainloader,validloader):
        
        # Optimization Loop
        
        for e in range(int(self.epochs)):
            
            start_time = time.time()
            
            running_loss = 0.
            
            for images, labels in trainloader:

              images = images.to(self.device)

              out, latent = self.forward(images)

              loss = self.criterion(out, images)

              running_loss += loss.item()*images.size(0)
            
              self.optim.zero_grad()

              loss.backward()

              self.optim.step()   

            self.loss_during_training.append(running_loss/len(trainloader))

            validation_total = 0 
            
            with torch.no_grad():        
              
              self.eval()    

              for images,labels in validloader:
                
                images=images.to(self.device)
                self.optim.zero_grad()

                validation_out,_ = self.forward(images)
                validation_loss = self.criterion(validation_out, images)
                validation_total += validation_loss.item()
              
              self.validation_loss_during_training.append(validation_total/len(validloader))  
              self.train()

            if(e % 1 == 0): # Every 10 epochs
              print("Epoch %d. Training loss: %f, Validation loss: %f, Time per epoch: %f seconds" 
                    %(e,self.loss_during_training[-1],self.validation_loss_during_training[-1],
                      (time.time() - start_time)))

# %% [markdown]
# > **Exercise:** Train the model for 10 epochs and plot both training and validation losses. Can you visualize overfitting?

# %%
my_cnnAut = ConvAutoencoderExtended(epochs=10,lr=1e-3)

my_cnnAut.trainloop(trainloader, validloader)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch 0. Training loss: 15.402375, Validation loss: 0.107908, Time per epoch: 14.494882 seconds
# Epoch 1. Training loss: 10.791570, Validation loss: 0.062833, Time per epoch: 14.489126 seconds
# Epoch 2. Training loss: 5.452611, Validation loss: 0.028406, Time per epoch: 14.605305 seconds
# Epoch 3. Training loss: 3.068276, Validation loss: 0.022358, Time per epoch: 14.396539 seconds
# Epoch 4. Training loss: 2.605917, Validation loss: 0.018960, Time per epoch: 14.613416 seconds
# Epoch 5. Training loss: 2.093398, Validation loss: 0.014665, Time per epoch: 14.495999 seconds
# Epoch 6. Training loss: 1.654441, Validation loss: 0.012158, Time per epoch: 14.220466 seconds
# Epoch 7. Training loss: 1.445785, Validation loss: 0.011153, Time per epoch: 14.087438 seconds
# Epoch 8. Training loss: 1.353189, Validation loss: 0.010582, Time per epoch: 14.151730 seconds
# Epoch 9. Training loss: 1.291433, Validation loss: 0.010146, Time per epoch: 14.095631 seconds

# %%
plt.figure()
plt.plot(my_cnnAut.loss_during_training,'b', label='Training_Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss evolution')
plt.legend()
plt.show()

# %%
plt.plot(my_cnnAut.validation_loss_during_training,'r', label='Validation_Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss evolution')
plt.legend()
plt.show()

# %% [markdown]
# `We really can't see overfitting with 10 epochs since the validation loss is not increasing yet. We might be able to overfit when increasing the number of epochs.`

# %% [markdown]
# ### Checking out the results
#
# Below we plot some of the **test images** along with their reconstructions. These look a little rough around the edges, likely due to the checkerboard effect we mentioned above that tends to happen with transpose layers.
#
# > **Exercise:** Complete the code (just one line!)

# %%
# obtain one batch of test images
dataiter = iter(testloader)
images, labels = dataiter.next()

# get sample outputs
output,latent = my_cnnAut(images)       
# prep images for display
images = images.numpy()

# output is resized into a batch of iages
output = output.view(batch_size, 1, 28, 28)
# use detach when it's an output that requires_grad
output = output.detach().numpy()

# plot the first ten input images and then reconstructed images
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(25,4))

# input images on top row, reconstructions on bottom
for i in range(10):
    axes[0,i].imshow(np.squeeze(images[i]), cmap='gray')
    axes[1,i].imshow(np.squeeze(output[i]), cmap='gray')

    axes[0,i].get_xaxis().set_visible(False) # Remove legend
    axes[0,i].get_yaxis().set_visible(False)
    axes[1,i].get_xaxis().set_visible(False) # Remove legend
    axes[1,i].get_yaxis().set_visible(False)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %% [markdown]
# ## Part IV. Projecting the images in a 2 dimensional space

# %% [markdown]
# The results are actually not bad at all!! Now, we are going to project the images in a space of only 2 dimensions (instead of `7x7x4=196`). Obviously, we expect **much worse** reconstruction quality. However, in this case we are indeed interested in the structure of the projected space (i.e. how the autoencoder organizes the images in the 2D latent space). Since reconstruction quality is not our goal, we will implement both the encoder and the decoder using only **two dense layers each**.
#
# > **Exercise:**
# > - Implement the described autoencoder. Use **hiperbolic tangent** activation functions. For shuch a small network, a `ReLU` does not provide good results.
# >
# > - Extend the class to incorporate the training loop and the evaluation of the loss function in the validation set during training
# >
# > - Train the model a few times and select the one that provides the best results (sometimes you will see the solution gets stuck in a very bad local optima). To do so, **create 10 objects of the same type, train each of them independently for 50 epochs, and finally select the one that provides the smallest validation loss**.
# >
# >- For the selected model, compute the encoder's latent representation in the 2D space for a mini-batch of images and visualize 2D projections using the following function:
#
# ```python
#
# from matplotlib.offsetbox import OffsetImage, AnnotationBbox
#
# def plot_latent_space_with_images(images,latent):
#
#     # images --> Minibatch of images (numpy array!)
#     # laent --> Matrix of 2D representations (numpy array!)
#
#     f, ax = plt.subplots(1,1,figsize=(8, 8))
#     # ax is a figure handle
#     ax.clear()
#     for i in range(len(images)):
#         im = OffsetImage(np.squeeze(images[i]), cmap='gray')
#         ab = AnnotationBbox(im, latent[i,:],frameon=False)
#         ax.add_artist(ab)
#     #We set the limits according to the maximum and minimum values found for the latent projections
#     ax.set_xlim(-1,1)
#     ax.set_ylim(-1,1)
#     ax.set_title('Latent space Z with Images')
#
# ```

# %%
class ConvAutoencoder2D(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.linear1 = nn.Linear(28,14)
        
        self.linear2 = nn.Linear(14,7)

        self.inverseLinear2 = nn.Linear(7,14)
        
        self.inverseLinear1 = nn.Linear(14,28)

    def forward(self, x):

        x = torch.tanh((self.linear1(x)))
        latent = torch.tanh((self.linear2(x)))

        x = torch.tanh(self.inverseLinear2((latent)))
        x = torch.sigmoid((self.inverseLinear1(x)))

        return x, latent

# %%
class ConvAutoencoder2DExtended(ConvAutoencoder2D):
    
    def __init__(self,epochs=100,lr=0.001):
        
        super().__init__() 
        
        self.lr = lr 
        
        self.optim = optim.Adam(self.parameters(), self.lr)
        
        self.epochs = epochs
        
        self.criterion = nn.SmoothL1Loss()
        
        self.loss_during_training = []
        
        self.validation_loss_during_training = []
    
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        self.to(self.device)
        
    def trainloop(self,trainloader,validloader):
        
        # Optimization Loop
        
        for e in range(int(self.epochs)):
            
            start_time = time.time()
            
            running_loss = 0.
            
            for images, labels in trainloader:

              images = images.to(self.device)

              out, latent = self.forward(images)

              loss = self.criterion(out, images)

              running_loss += loss.item()*images.size(0)
            
              self.optim.zero_grad()

              loss.backward()

              self.optim.step()   

            self.loss_during_training.append(running_loss/len(trainloader))

            validation_total = 0 
            
            with torch.no_grad():        
              
              self.eval()    

              for images,labels in validloader:
                
                images=images.to(self.device)
                self.optim.zero_grad()

                validation_out,_ = self.forward(images)
                validation_loss = self.criterion(validation_out, images)
                validation_total += validation_loss.item()
              
              self.validation_loss_during_training.append(validation_total/len(validloader))  
              self.train()

            if(e % 10 == 0): # Every 10 epochs
              print("Epoch %d. Training loss: %f, Validation loss: %f, Time per epoch: %f seconds" 
                    %(e,self.loss_during_training[-1],self.validation_loss_during_training[-1],
                      (time.time() - start_time)))

# %%
val_losses = []

for i in np.arange(10):

  print('Model ', i+1)
  print('\n')
  
  my_cnnAut_2D = ConvAutoencoder2DExtended(epochs=50,lr=1e-3)
  my_cnnAut_2D.trainloop(trainloader, validloader)

  val_losses.append(my_cnnAut_2D.validation_loss_during_training[-1])

  print('\n')
  print('---------------------------------------------------------------------------------------------')
  print('\n')

  if(len(val_losses) > 1):
    if(val_losses[i] < val_losses[i-1]):
      best_model = my_cnnAut_2D
# Out:
# Model  1
#
#
# Epoch 0. Training loss: 26.459678, Validation loss: 0.191623, Time per epoch: 5.377766 seconds
# Epoch 10. Training loss: 10.187851, Validation loss: 0.081432, Time per epoch: 5.398098 seconds
# Epoch 20. Training loss: 10.078992, Validation loss: 0.080570, Time per epoch: 5.512583 seconds
# Epoch 30. Training loss: 5.625459, Validation loss: 0.043768, Time per epoch: 5.603967 seconds
# Epoch 40. Training loss: 3.403835, Validation loss: 0.026742, Time per epoch: 5.613744 seconds
#
#
# ---------------------------------------------------------------------------------------------
#
#
# Model  2
#
#
# Epoch 0. Training loss: 27.025760, Validation loss: 0.194442, Time per epoch: 5.652167 seconds
# Epoch 10. Training loss: 7.169985, Validation loss: 0.055893, Time per epoch: 5.509636 seconds
# Epoch 20. Training loss: 5.111715, Validation loss: 0.040372, Time per epoch: 5.416476 seconds
# Epoch 30. Training loss: 3.182375, Validation loss: 0.025120, Time per epoch: 5.137949 seconds
# Epoch 40. Training loss: 2.466305, Validation loss: 0.019573, Time per epoch: 5.155125 seconds
#
#
# ---------------------------------------------------------------------------------------------
#
#
# Model  3
#
#
# Epoch 0. Training loss: 27.121081, Validation loss: 0.191995, Time per epoch: 5.213792 seconds
# Epoch 10. Training loss: 9.892552, Validation loss: 0.078029, Time per epoch: 5.291561 seconds
# Epoch 20. Training loss: 5.890105, Validation loss: 0.046115, Time per epoch: 5.488682 seconds
# Epoch 30. Training loss: 4.304184, Validation loss: 0.033357, Time per epoch: 5.478814 seconds
# Epoch 40. Training loss: 2.780887, Validation loss: 0.021949, Time per epoch: 5.554446 seconds
#
#
# ---------------------------------------------------------------------------------------------
#
#
# Model  4
#
#
# Epoch 0. Training loss: 26.369463, Validation loss: 0.189041, Time per epoch: 5.433222 seconds
# Epoch 10. Training loss: 9.912711, Validation loss: 0.078738, Time per epoch: 5.330138 seconds
# Epoch 20. Training loss: 5.720662, Validation loss: 0.044743, Time per epoch: 5.467123 seconds
# Epoch 30. Training loss: 3.643400, Validation loss: 0.028394, Time per epoch: 5.291400 seconds
# Epoch 40. Training loss: 2.781787, Validation loss: 0.022145, Time per epoch: 5.392076 seconds
#
#
# ---------------------------------------------------------------------------------------------
#
#
# Model  5
#
#
# Epoch 0. Training loss: 27.300254, Validation loss: 0.197438, Time per epoch: 5.532514 seconds
# Epoch 10. Training loss: 7.663957, Validation loss: 0.058731, Time per epoch: 5.202132 seconds
# Epoch 20. Training loss: 4.866581, Validation loss: 0.037391, Time per epoch: 5.150669 seconds
# Epoch 30. Training loss: 2.999053, Validation loss: 0.023757, Time per epoch: 4.941233 seconds
# Epoch 40. Training loss: 2.464291, Validation loss: 0.019642, Time per epoch: 5.180283 seconds
#
#
# ---------------------------------------------------------------------------------------------
#
#
# Model  6
#
#
# Epoch 0. Training loss: 26.263961, Validation loss: 0.185399, Time per epoch: 5.480273 seconds
# Epoch 10. Training loss: 10.122871, Validation loss: 0.080535, Time per epoch: 5.276178 seconds
# Epoch 20. Training loss: 5.665780, Validation loss: 0.044266, Time per epoch: 5.203508 seconds
# Epoch 30. Training loss: 4.298554, Validation loss: 0.033585, Time per epoch: 5.516505 seconds
# Epoch 40. Training loss: 2.578349, Validation loss: 0.020421, Time per epoch: 5.691663 seconds
#
#
# ---------------------------------------------------------------------------------------------
#
#
# Model  7
#
#
# Epoch 0. Training loss: 28.764902, Validation loss: 0.207446, Time per epoch: 5.486961 seconds
# Epoch 10. Training loss: 6.855351, Validation loss: 0.053509, Time per epoch: 5.473061 seconds
# Epoch 20. Training loss: 5.004520, Validation loss: 0.039612, Time per epoch: 5.507265 seconds
# Epoch 30. Training loss: 3.147628, Validation loss: 0.024817, Time per epoch: 5.435697 seconds
# Epoch 40. Training loss: 2.516285, Validation loss: 0.020004, Time per epoch: 5.352061 seconds
#
#
# ---------------------------------------------------------------------------------------------
#
#
# Model  8
#
#
# Epoch 0. Training loss: 28.279184, Validation loss: 0.202966, Time per epoch: 5.412083 seconds
# Epoch 10. Training loss: 10.188136, Validation loss: 0.081419, Time per epoch: 5.347365 seconds
# Epoch 20. Training loss: 7.683865, Validation loss: 0.058485, Time per epoch: 5.521375 seconds
# Epoch 30. Training loss: 4.792389, Validation loss: 0.037978, Time per epoch: 5.474308 seconds
# Epoch 40. Training loss: 3.004710, Validation loss: 0.023669, Time per epoch: 5.320864 seconds
#
#
# ---------------------------------------------------------------------------------------------
#
#
# Model  9
#
#
# Epoch 0. Training loss: 26.962158, Validation loss: 0.193950, Time per epoch: 5.355006 seconds
# Epoch 10. Training loss: 10.217300, Validation loss: 0.081652, Time per epoch: 5.448117 seconds
# Epoch 20. Training loss: 10.087809, Validation loss: 0.080615, Time per epoch: 5.407336 seconds
# Epoch 30. Training loss: 5.770678, Validation loss: 0.044975, Time per epoch: 5.190004 seconds
# Epoch 40. Training loss: 3.887270, Validation loss: 0.030004, Time per epoch: 5.507041 seconds
#
#
# ---------------------------------------------------------------------------------------------
#
#
# Model  10
#
#
# Epoch 0. Training loss: 27.472818, Validation loss: 0.201157, Time per epoch: 5.384907 seconds
# Epoch 10. Training loss: 10.188609, Validation loss: 0.081435, Time per epoch: 5.255082 seconds
# Epoch 20. Training loss: 8.239841, Validation loss: 0.063147, Time per epoch: 5.435945 seconds
# Epoch 30. Training loss: 5.034856, Validation loss: 0.039639, Time per epoch: 5.048362 seconds
# Epoch 40. Training loss: 3.221464, Validation loss: 0.025388, Time per epoch: 5.227238 seconds
#
#
# ---------------------------------------------------------------------------------------------

# %%
print('Minimum validation loss for model 0: ', min(val_losses))
# Out:
# Minimum validation loss for model 0:  0.01514245848236389

# %% [markdown]
# As we can see, model 8 has de best validation loss, therefore we'll keep it.

# %%
plt.figure()
plt.plot(best_model.loss_during_training,'b', label='Training_Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss evolution')
plt.legend()
plt.show()

# %%
plt.plot(best_model.validation_loss_during_training,'r', label='Validation_Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss evolution')
plt.legend()
plt.show()

# %%
# obtain one batch of test images
dataiter = iter(testloader)
images, labels = dataiter.next()

# get sample outputs
output,latent = best_model(images)       
# prep images for display
images = images.numpy()

# output is resized into a batch of iages
output = output.view(batch_size, 1, 28, 28)
# use detach when it's an output that requires_grad
output = output.detach().numpy()

# plot the first ten input images and then reconstructed images
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(25,4))

# input images on top row, reconstructions on bottom
for i in range(10):
    axes[0,i].imshow(np.squeeze(images[i]), cmap='gray')
    axes[1,i].imshow(np.squeeze(output[i]), cmap='gray')

    axes[0,i].get_xaxis().set_visible(False) # Remove legend
    axes[0,i].get_yaxis().set_visible(False)
    axes[1,i].get_xaxis().set_visible(False) # Remove legend
    axes[1,i].get_yaxis().set_visible(False)
